# %% [markdown]
# # Explore here

# %%
# Your code here

import pandas as pd

url = "https://raw.githubusercontent.com/4GeeksAcademy/decision-tree-project-tutorial/main/diabetes.csv"

total_data = pd.read_csv(url)

print(total_data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
total_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
total_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
null_counts = total_data.isnull().sum()
print(null_counts)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(total_data.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap of Variables')
plt.show()

# %%
total_data.drop(['BloodPressure', 'SkinThickness', 'Pregnancies'], axis=1, inplace=True)
total_data.head()
# Out:
#    Glucose  Insulin   BMI  DiabetesPedigreeFunction  Age  Outcome
# 0      148        0  33.6                     0.627   50        1
# 1       85        0  26.6                     0.351   31        0
# 2      183        0  23.3                     0.672   32        1
# 3       89       94  28.1                     0.167   21        0
# 4      137      168  43.1                     2.288   33        1

# %%
total_data.describe()
# Out:
#           Glucose     Insulin         BMI  DiabetesPedigreeFunction  \
# count  768.000000  768.000000  768.000000                768.000000
# mean   120.894531   79.799479   31.992578                  0.471876
# std     31.972618  115.244002    7.884160                  0.331329
# min      0.000000    0.000000    0.000000                  0.078000
# 25%     99.000000    0.000000   27.300000                  0.243750
# 50%    117.000000   30.500000   32.000000                  0.372500
# 75%    140.250000  127.250000   36.600000                  0.626250
# max    199.000000  846.000000   67.100000                  2.420000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
plt.figure(figsize=(10, 6))
plt.hist(total_data['Glucose'], bins=20, color='lightgreen', edgecolor='black', alpha=0.7)
plt.title('Histogram of Glucose')
plt.xlabel('Glucose Level')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
def replace_values(val):
    if val < 50:
        return 50
    else:
        return val

total_data['Glucose'] = total_data['Glucose'].apply(replace_values)
total_data.describe()
# Out:
#           Glucose     Insulin         BMI  DiabetesPedigreeFunction  \
# count  768.000000  768.000000  768.000000                768.000000
# mean   121.227865   79.799479   31.992578                  0.471876
# std     30.959138  115.244002    7.884160                  0.331329
# min     50.000000    0.000000    0.000000                  0.078000
# 25%     99.000000    0.000000   27.300000                  0.243750
# 50%    117.000000   30.500000   32.000000                  0.372500
# 75%    140.250000  127.250000   36.600000                  0.626250
# max    199.000000  846.000000   67.100000                  2.420000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
plt.figure(figsize=(10, 6))
plt.hist(total_data['Insulin'], bins=20, color='lightcoral', edgecolor='black', alpha=0.7)
plt.title('Histogram of Insulin')
plt.xlabel('Insulin Level')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(total_data['BMI'], bins=20, color='orange', edgecolor='black', alpha=0.7)
plt.title('Histogram of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
mean_bmi = total_data.loc[total_data['BMI'] != 0, 'BMI'].mean()
total_data['BMI'] = total_data['BMI'].replace(0, mean_bmi)
total_data.describe()
# Out:
#           Glucose     Insulin         BMI  DiabetesPedigreeFunction  \
# count  768.000000  768.000000  768.000000                768.000000
# mean   121.227865   79.799479   32.457464                  0.471876
# std     30.959138  115.244002    6.875151                  0.331329
# min     50.000000    0.000000   18.200000                  0.078000
# 25%     99.000000    0.000000   27.500000                  0.243750
# 50%    117.000000   30.500000   32.400000                  0.372500
# 75%    140.250000  127.250000   36.600000                  0.626250
# max    199.000000  846.000000   67.100000                  2.420000
#
#               Age     Outcome
# count  768.000000  768.000000
# mean    33.240885    0.348958
# std     11.760232    0.476951
# min     21.000000    0.000000
# 25%     24.000000    0.000000
# 50%     29.000000    0.000000
# 75%     41.000000    1.000000
# max     81.000000    1.000000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn import tree
import matplotlib.pyplot as plt

X = total_data.drop('Outcome', axis=1)  
y = total_data['Outcome']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

X_train["Outcome"] = y_train.values
X_test["Outcome"] = y_test.values
X_train.to_csv("../data/processed/clean_train.csv", index = False)
X_test.to_csv("../data/processed/clean_test.csv", index = False)

# %%
clf = DecisionTreeClassifier(
    max_depth=5,
    min_samples_split=5,
    min_samples_leaf=2,
    max_features='sqrt',
    criterion='gini')

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.948051948051948

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       151
#            1       0.94      0.91      0.92        80
#
#     accuracy                           0.95       231
#    macro avg       0.95      0.94      0.94       231
# weighted avg       0.95      0.95      0.95       231
#
#
# Confusion Matrix:
# [[146   5]
#  [  7  73]]

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(clf, filled=True, feature_names=['Glucose', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'], class_names=['No Diabetes', 'Diabetes'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 plt.figure(figsize=(20,10))
# ----> 2 tree.plot_tree(clf, filled=True, feature_names=['Glucose', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'], class_names=['No Diabetes', 'Diabetes'])
#       3 plt.show()
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\tree\_export.py:211, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     196 check_is_fitted(decision_tree)
#     198 exporter = _MPLTreeExporter(
#     199     max_depth=max_depth,
#     200     feature_names=feature_names,
#    (...)
#     209     fontsize=fontsize,
#     210 )
# --> 211 return exporter.export(decision_tree, ax=ax)
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\tree\_export.py:643, in _MPLTreeExporter.export(self, decision_tree, ax)
#     641 ax.clear()
#     642 ax.set_axis_off()
# --> 643 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     644 draw_tree = buchheim(my_tree)
#     646 # important to make sure we're still
#     647 # inside the axis after drawing the box
#     648 # this makes sense because the width of a box
#     649 # is about the same as the distance between boxes
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\tree\_export.py:624, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     619 name = self.node_to_str(et, node_id, criterion=criterion)
#     620 if et.children_left[node_id] != _tree.TREE_LEAF and (
#     621     self.max_depth is None or depth <= self.max_depth
#     622 ):
#     623     children = [
# --> 624         self._make_tree(
#     625             et.children_left[node_id], et, criterion, depth=depth + 1
#     626         ),
#     627         self._make_tree(
#     628             et.children_right[node_id], et, criterion, depth=depth + 1
#     629         ),
#     630     ]
#     631 else:
#     632     return Tree(name, node_id)
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\tree\_export.py:619, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     616 def _make_tree(self, node_id, et, criterion, depth=0):
#     617     # traverses _tree.Tree recursively, builds intermediate
#     618     # "_reingold_tilford.Tree" object
# --> 619     name = self.node_to_str(et, node_id, criterion=criterion)
#     620     if et.children_left[node_id] != _tree.TREE_LEAF and (
#     621         self.max_depth is None or depth <= self.max_depth
#     622     ):
#     623         children = [
#     624             self._make_tree(
#     625                 et.children_left[node_id], et, criterion, depth=depth + 1
#    (...)
#     629             ),
#     630         ]
#
# File c:\Users\triba\anaconda3\envs\GPU\lib\site-packages\sklearn\tree\_export.py:310, in _BaseTreeExporter.node_to_str(self, tree, node_id, criterion)
#     307 if tree.children_left[node_id] != _tree.TREE_LEAF:
#     308     # Always write node decision criteria, except for leaves
#     309     if self.feature_names is not None:
# --> 310         feature = self.feature_names[tree.feature[node_id]]
#     311     else:
#     312         feature = "x%s%s%s" % (
#     313             characters[1],
#     314             tree.feature[node_id],
#     315             characters[2],
#     316         )
#
# IndexError: list index out of range

# %%
feature_importances = pd.DataFrame({'Feature': X.columns, 'Importance': clf.feature_importances_})
feature_importances = feature_importances.sort_values(by='Importance', ascending=False)
print("\nFeature Importances:")
print(feature_importances)
# Out:
# Feature Importances:
#                     Feature  Importance
# 0                   Glucose    0.381479
# 4                       Age    0.312373
# 2                       BMI    0.161449
# 3  DiabetesPedigreeFunction    0.100688
# 1                   Insulin    0.044011
